# %%
#### 다음 실습 코드는 학습 목적으로만 사용 바랍니다. 문의 : audit@korea.ac.kr 임성열 Ph.D.

'''Python 3.13에서는 아직 TensorFlow가 공식 지원 안됨. Python 3.11 이하 (특히 3.9, 3.10, 3.11) 사용 권고 

# 여러 버전의 Python을 설치하고 관리해야 한다면, pyenv 또는 anaconda 등으로 여러 버전의 Python 설치 후 프로젝트별 버전 전환 관리할 수 있음
# 또는 직접 수동으로 각각 Python 버전 설치도 가능하나 각 실행 파일 디렉토리 위치 경로를 수작업으로 관리 필요

# 파이썬 버전 제어 및 범용 개발이 중심이라면 → 🧑‍💻 pyenv + venv/poetry 조합 추천
# 데이터 과학/머신러닝 중심이라면 → 🎯 Anaconda (또는 Miniconda) 권장
# 빠른 개발 및 배포 → 📦 forge는 최근 등장한 관리 도구로 Jupyter 환경 설정 별도 필요, 아직 패키지 배포 자동화 및 GPU 지원 미비

# Python 버전 낮추기 또는 여러 버전 이용 (예시) : 

# 🧑‍💻 pyenv 설치 후, pyenv install 3.10.13
# pyenv global 3.10.13   # 또는 pyenv local 3.10.13 (현재 폴더만)
# pip install numpy matplotlib pandas scikit-learn tensorflow

# 🎯 anaconda (https://www.anaconda.com/products/distribution) 설치 후 
# conda create -n tf python=3.10.13
# conda activate tf
# pip install numpy matplotlib pandas scikit-learn tensorflow

# 🧪 모두 다 설치했다면 → 하나의 목적에만 집중해 사용하는 것이 충돌 방지에 좋음'''

# Installing the packeges
'''graphviz는 먼저 OS 패키지 설치 필요 (리눅스 : apt-get install graphviz, 맥 OS : brew install graphviz)
# 윈도우는 다음과 같이 직접 설치 필요
 1. Graphviz 공식 다운로드 페이지 접속 (https://graphviz.org/download/)
 2. Windows installer (exe) 파일 다운로드 후 설치
 3. 설치 경로(C:\Program Files\Graphviz\bin)를 환경 변수 PATH에 추가'''
 
# !python -m pip uninstall -y tensorflow keras
# !python -m pip install -U "tensorflow==2.19.*" "keras>=3.11,<4"
# Out:
# Found existing installation: tensorflow 2.19.1
# Uninstalling tensorflow-2.19.1:
#   Successfully uninstalled tensorflow-2.19.1
# Found existing installation: keras 3.14.0
# Uninstalling keras-3.14.0:
#   Successfully uninstalled keras-3.14.0
# Collecting tensorflow==2.19.*
#   Using cached tensorflow-2.19.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (4.0 kB)
# Collecting keras<4,>=3.11
#   Using cached keras-3.14.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorflow==2.19.*) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorflow==2.19.*) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorflow==2.19.*) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorflow==2.19.*) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorflow==2.19.*) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorflow==2.19.*) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorflow==2.19.*) (3.4.0)
# Requirement already satisfied: packaging in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorflow==2.19.*) (26.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorflow==2.19.*) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorflow==2.19.*) (2.33.1)
# Requirement already satisfied: setuptools in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorflow==2.19.*) (80.10.2)
# Requirement already satisfied: six>=1.12.0 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorflow==2.19.*) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorflow==2.19.*) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorflow==2.19.*) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorflow==2.19.*) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorflow==2.19.*) (1.80.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorflow==2.19.*) (2.19.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorflow==2.19.*) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorflow==2.19.*) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorflow==2.19.*) (0.5.4)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorflow==2.19.*) (0.37.1)
# Requirement already satisfied: rich in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from keras<4,>=3.11) (14.3.3)
# Requirement already satisfied: namex in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from keras<4,>=3.11) (0.1.0)
# Requirement already satisfied: optree in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from keras<4,>=3.11) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.19.*) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.19.*) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.19.*) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.19.*) (2026.2.25)
# Requirement already satisfied: markdown>=2.6.8 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow==2.19.*) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow==2.19.*) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow==2.19.*) (3.1.8)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow==2.19.*) (0.46.3)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow==2.19.*) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from rich->keras<4,>=3.11) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from rich->keras<4,>=3.11) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/rieioa/Documents/Workspace/model_serving_rpt/myenv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras<4,>=3.11) (0.1.2)
# Using cached tensorflow-2.19.1-cp311-cp311-macosx_12_0_arm64.whl (252.6 MB)
# Using cached keras-3.14.0-py3-none-any.whl (1.6 MB)
# Installing collected packages: keras, tensorflow
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [tensorflow] 1/2 [tensorflow]
# Successfully installed keras-3.14.0 tensorflow-2.19.1
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional

import math
from sklearn.metrics import mean_squared_error

# %%
# Some functions to help out with
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Real IBM Stock Price')
    plt.plot(predicted, color='blue',label='Predicted IBM Stock Price')
    plt.title('IBM Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel('IBM Stock Price')
    plt.legend()
    plt.show()

def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))

# %%
# Connectiing Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# Loading the data
dataset = pd.read_csv('../uploaded_files/IBM_2006-01-01_to_2018-01-01.csv', index_col='Date', parse_dates=['Date'])
dataset.head()
# Out:
#              Open   High    Low  Close    Volume Name
# Date
# 2006-01-03  82.45  82.55  80.81  82.06  11715200  IBM
# 2006-01-04  82.20  82.50  81.33  81.95   9840600  IBM
# 2006-01-05  81.40  82.90  81.00  82.50   7213500  IBM
# 2006-01-06  83.95  85.03  83.41  84.95   8197400  IBM
# 2006-01-09  84.10  84.25  83.38  83.73   6858200  IBM

# %%
# Checking for missing values
# 2016년도이전 데이터에서 2번째 컬럼 값을 가져와서 저장합니다.
training_set = dataset[:'2016'].iloc[:,1:2].values
# 2017년도이후 데이터에서 2번째 컬럼 값을 가져와서 저장합니다.
test_set = dataset['2017':].iloc[:,1:2].values

# We have chosen 'High' attribute for prices. Let's see what it looks like
dataset["High"][:'2016'].plot(figsize=(16,4),legend=True)
dataset["High"]['2017':].plot(figsize=(16,4),legend=True)
plt.legend(['Training set (Before 2017)','Test set (2017 and beyond)'])
plt.title('IBM stock price')
plt.show()

# %%
import os
import time
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler

# (진단/우회) 일반적으로 LSTM은 GPU 효율이 낮은 구조임, 맥에서 첫 배치 hang를 피하기 위한 설정 (리눅스나 윈도우에는 영향 없음)
# GPU/메탈 런타임에서 첫 배치가 멈추는 경우가 있어 CPU로 강제해 진단/우회 (GPU가 맞는 데이터 특성, 대형 행렬 곱 : CNN, Transformer, 대규모 벡터 연산)
# 모델/텐서 연산 전에 실행
try:
    tf.config.set_visible_devices([], "GPU") # GPU를 쓰기에는 너무 작은 데이터로 CPU로 처리 (2709 × 60 × 1)
except Exception:
    pass

# XLA(JIT) 관련 이슈를 배제하기 위해 비활성화
try:
    tf.config.optimizer.set_jit(False)
except Exception:
    pass

# Scaling the training set

sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set).astype(np.float32)

# Since LSTMs store long term memory state, we create a data structure with 60 timesteps and 1 output
# So for each element of training set, we have 60 previous training set elements
X_train = []
y_train = []
# LSTM 시계열 분석을 위해, Timesteps를 60으로 할 것이므로 60행 이후 데이터부터 사용 가능
# 데이터 셋을 보면, 2016년 데이터가 전체 2769개 존재함
# 데이터 길이에 맞게 자동 계산하도록 수정 (또는 2769로 하드코딩도 가능하나, 비추천)
for i in range(60, len(training_set_scaled)):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])

X_train, y_train = np.array(X_train, dtype=np.float32), np.array(y_train, dtype=np.float32)

# Reshaping X_train for efficient modelling
# Timesteps와 MinMaxScaler 등을 적용한 대상 데이터를, LTSM Layer 입력에 용이하게 재배치
# shape[0]는 전체 행의 갯수, shape[1]은 전체 열의 갯수인데.. 상기 np 배열에 넣은 형태로 여기서는 잘라낸 Timesteps 갯수
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
# X_train = np.reshape(X_train, (2709,60,1))을 뜻하며, 2016년이전 2709개의 행을 60개씩 끊어낸 값 1행으로
# LSTM (시계열성 데이터 변경 이력 예측에 특화된 RNN모델) input_shape에 맞게 3차원 배열로 재구성

# (진단) 입력 확인
print("[debug] X_train:", X_train.shape, X_train.dtype, "finite:", np.isfinite(X_train).all())
print("[debug] y_train:", y_train.shape, y_train.dtype, "finite:", np.isfinite(y_train).all())
print("[debug] GPUs:", tf.config.list_physical_devices("GPU"))
print("[debug] CPUs:", tf.config.list_physical_devices("CPU"))

# The LSTM architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense

regressor = Sequential()

# 입력 정의 (X_train: (samples, timesteps, features) 가정)
regressor.add(Input(shape=(X_train.shape[1], 1)))

# First LSTM layer with Dropout regularisation
# 50개의 노드를 사용하여 RNN, LSTM 방식으로 입력층, 은닉층 생성
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))
# 전체 가능한 데이터 범위는 2709행에 대해서 60개 단위로 자동 계산되므로 생략
# 60개씩 끊어내서, 1개의 Feature에 대해서 예측

# Second LSTM layer
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

# Third LSTM layer
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

# Fourth LSTM layer
regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))

# The output layer
regressor.add(Dense(units=1))
# 최종 결과가 60개씩 시계열 이력 데이터를 끊어낸 단위에 대해 학습한 결과, 값 예측이므로 마지막 노드는 1개로 처리
# 단, MNIST 이미지 데이터와 같이, 0~9까지 표현을 위해 최종 노드를 사용하는 경우 10개 노드 필요

# Compiling the RNN
regressor.compile(optimizer='adam', loss='mean_squared_error')

# Fitting to the training set
# 시계열 데이터 특성상 shuffle=False 권장
# verbose=1 설정으로 epoch 진행 상황을 명확히 출력
# batch_size는 학습 속도에 영향을 미침
regressor.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    shuffle=False,
    verbose=1
)
# Out:
# [debug] X_train: (2709, 60, 1) float32 finite: True
# [debug] y_train: (2709,) float32 finite: True
# [debug] GPUs: []
# [debug] CPUs: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# Epoch 1/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0105
# Epoch 2/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0126
# Epoch 3/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0088
# Epoch 4/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0101
# Epoch 5/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0084
# Epoch 6/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0078
# Epoch 7/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0071
# Epoch 8/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0075
# Epoch 9/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0077
# Epoch 10/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0083
# Epoch 11/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0102
# Epoch 12/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0145
# Epoch 13/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0186
# Epoch 14/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0217
# Epoch 15/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0279
# Epoch 16/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0265
# Epoch 17/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0277
# Epoch 18/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0241
# Epoch 19/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0281
# Epoch 20/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0153
# Epoch 21/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0163
# Epoch 22/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0102
# Epoch 23/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0122
# Epoch 24/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0149
# Epoch 25/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0164
# Epoch 26/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0162
# Epoch 27/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0155
# Epoch 28/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0156
# Epoch 29/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0147
# Epoch 30/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0133
# Epoch 31/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0125
# Epoch 32/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0116
# Epoch 33/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0113
# Epoch 34/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0109
# Epoch 35/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0105
# Epoch 36/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0107
# Epoch 37/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0112
# Epoch 38/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0103
# Epoch 39/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0088
# Epoch 40/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0083
# Epoch 41/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0080
# Epoch 42/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0080
# Epoch 43/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0077
# Epoch 44/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0079
# Epoch 45/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0079
# Epoch 46/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0079
# Epoch 47/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0071
# Epoch 48/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0066
# Epoch 49/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0062
# Epoch 50/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0066

# %%
# Now to get the test set ready in a similar way as the training set.
# The following has been done so forst 60 entires of test set have 60 previous values which is impossible to get unless we take the whole
# 'High' attribute data for processing
dataset_total = pd.concat((dataset["High"][:'2016'],dataset["High"]['2017':]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.transform(inputs)

# Preparing X_test and predicting the prices
X_test = []
for i in range(60,311):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# Visualizing the results for LSTM
plot_predictions(test_set,predicted_stock_price)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
# Evaluating our model
return_rmse(test_set,predicted_stock_price)
# Out:
# The root mean squared error is 6.7447658653608755.

# %%
# 1. 모델 저장하기
from keras.models import load_model

# regressor.save('/content/drive/MyDrive/data/stock_lstm_model_nogpu.h5')
regressor.save('../model/stock_lstm_model_nogpu.keras')

# %%
# 2. 모델 불러오기
import pandas as pd
from keras.models import load_model

# Connectiing Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# Loading the model
model = load_model('../model/stock_lstm_model_nogpu.keras')

# Loading the data
dataset = pd.read_csv('../uploaded_files/IBM_2006-01-01_to_2018-01-01.csv', index_col='Date', parse_dates=['Date'])

# We have chosen 'High' attribute for prices.
dataset.head()
# Out:
#              Open   High    Low  Close    Volume Name
# Date
# 2006-01-03  82.45  82.55  80.81  82.06  11715200  IBM
# 2006-01-04  82.20  82.50  81.33  81.95   9840600  IBM
# 2006-01-05  81.40  82.90  81.00  82.50   7213500  IBM
# 2006-01-06  83.95  85.03  83.41  84.95   8197400  IBM
# 2006-01-09  84.10  84.25  83.38  83.73   6858200  IBM

# %%
# 3. 모델 아키텍처 보기
from keras.utils import plot_model
import pydot
import graphviz

# plot_model(model, to_file='/content/drive/MyDrive/data/model.png')
# plot_model(model, to_file='/content/drive/MyDrive/data/model_shapes.png', show_shapes=True)

plot_model(model, to_file='../model-images/model_service.png')
plot_model(model, to_file='../model-images/model_shapes.png', show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
# 4. 모델 사용하기
'''사용 순서
1. 데이터 파일을 입력 받아서 IBM_2006-01-01_to_2018-01-01.csv
2. 로딩한 모델로 예측한 후에 stock_lstm_model.keras
3. 결과를 stock.png 파일로 생성하여 내보내는 순서'''

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
# from keras.models import Sequential # 모델 학습 시에 사용하였으나, 모델을 재사용하는 것이므로 불필요
# from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional # 모델 학습 시에 사용하였으나, 모델을 재사용하는 것이므로 불필요
import math
from sklearn.metrics import mean_squared_error

# Some functions to help out with
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Real IBM Stock Price')
    plt.plot(predicted, color='blue',label='Predicted IBM Stock Price')
    plt.title('IBM Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel('IBM Stock Price')
    plt.legend()
  # plt.show()
  # plt.savefig('/content/drive/MyDrive/data/stock.png')
    plt.savefig('/Users/phoenix/Eagle/2026_MLOps/service_model/model_serving/server/model-images/stock.png')  

def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))

# Checking for missing values
training_set = dataset[:'2016'].iloc[:,1:2].values
test_set = dataset['2017':].iloc[:,1:2].values

# Scaling the training set
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# Now to get the test set ready in a similar way as the training set.
# The following has been done so forst 60 entires of test set have 60 previous values which is impossible to get unless we take the whole
# 'High' attribute data for processing
dataset_total = pd.concat((dataset["High"][:'2016'],dataset["High"]['2017':]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.transform(inputs)

# Preparing X_test and predicting the prices
X_test = []
for i in range(60,311):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# Visualizing the results for LSTM
plot_predictions(test_set,predicted_stock_price)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step

# %%
# Evaluating our model
return_rmse(test_set,predicted_stock_price)
# Out:
# The root mean squared error is 3.1128447385802094.

# %%
import sys
print(sys.version)
# Out:
# 3.11.13 (main, Jun  3 2025, 18:38:25) [Clang 16.0.0 (clang-1600.0.26.6)]
